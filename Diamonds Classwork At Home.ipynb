# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("Diamonds.csv"
# Out:
#   File "<ipython-input-4-7f77d6d52915>", line 1
#     df = pd.read_csv("Diamonds.csv"
#                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
df = pd.read_csv("Diamonds.csv")

# %%
df = pd.read
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-fbc520ff9b79> in <module>()
# ----> 1 df = pd.read
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
location = "Diamonds.csv"

# %%
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
sns.lmplot(x='cut',y='price', data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1b8c4218f1f2> in <module>()
# ----> 1 sns.lmplot(x='cut',y='price', data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     588         scatter_kws=scatter_kws, line_kws=line_kws,
#     589         )
# --> 590     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     591
#     592     # Add a legend
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     795
#     796             # Draw the plot
# ...

# %%
sns.lmplot(x='carat',y='price', data=df)

# %%
sns.lmplot(data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-73bf23963448> in <module>()
# ----> 1 sns.lmplot(data=df)
#
# TypeError: lmplot() missing 2 required positional arguments: 'x' and 'y'

# %%
# %matplotlib inline

# %%
sns.lmplot(x='carat',y='price', data=df)

# %%
stats_df = df.drop(['carat', 'Unnamed: 0', 'price'], axis=1)

# %%
stats_df.head()
# Out:
#        cut color clarity  depth  table     x     y     z
# 0    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2     Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4     Good     J     SI2   63.3   58.0  4.34  4.35  2.75

# %%
sns.boxplot(data=df)

# %%
df.rename(columns={'Unnamed:0':'number'}, inplace = true
# Out:
#   File "<ipython-input-18-7cc12ba7ae55>", line 1
#     df.rename(columns={'Unnamed:0':'number'}, inplace = true
#                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
df.rename(columns={'Unamed:0':'number'}, inplace = true
# Out:
#   File "<ipython-input-19-232f522bd31e>", line 1
#     df.rename(columns={'Unamed:0':'number'}, inplace = true
#                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
sns.boxplot(data=stats_df)

# %%
sns.distplot(df['depth'])

# %%
sns.distplot(df['table'])

# %%
sns.distplot(df['x'])

# %%
sns.distplot(df['y'])

# %%
sns.distplot(df['z'])

# %%
df.rename(columns={'Unnamed:0':'Number'}, inplace = true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-9b31b6a1d6b4> in <module>()
# ----> 1 df.rename(columns={'Unnamed:0':'Number'}, inplace = true)
#
# NameError: name 'true' is not defined

# %%
df.rename(columns={'Unnamed:0':'Number'}, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.rename(columns={'Unnamed:0':'Number'}, inplace = True)

# %%
sns.boxplot(data=stats_df)

# %%
df.rename(columns={'Unnamed:0':'Number'}, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.rename(columns={'Unnamed: 0':'Number'}, inplace = True)

# %%
df.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price     x     y     z
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.rename(columns={'x':'Length'}, inplace = True)

# %%
df.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price  Length     y  \
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326    3.95  3.98
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326    3.89  3.84
# 2       3   0.23     Good     E     VS1   56.9   65.0    327    4.05  4.07
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334    4.20  4.23
# 4       5   0.31     Good     J     SI2   63.3   58.0    335    4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.rename(columns={'y':'Width'}, inplace = True)

# %%
df.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price  Length  Width  \
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       3   0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       5   0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.rename(columns={'z':'Depth'}, inplace = True)

# %%
df.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price  Length  Width  \
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       3   0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       5   0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#    Depth
# 0   2.43
# 1   2.31
# 2   2.31
# 3   2.63
# 4   2.75

# %%
sns.distplot(df['Number'])

# %%
sns.violinplot(x='Carat', y='Number', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-9d97d30ac4a9> in <module>()
# ----> 1 sns.violinplot(x='Carat', y='Number', data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2343                              bw, cut, scale, scale_hue, gridsize,
#    2344                              width, inner, split, dodge, orient, linewidth,
# -> 2345                              color, palette, saturation)
#    2346
#    2347     if ax is None:
#
# ...

# %%
sns.violinplot(x='Number', y='Carat', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-edff5b87ef04> in <module>()
# ----> 1 sns.violinplot(x='Number', y='Carat', data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2343                              bw, cut, scale, scale_hue, gridsize,
#    2344                              width, inner, split, dodge, orient, linewidth,
# -> 2345                              color, palette, saturation)
#    2346
#    2347     if ax is None:
#
# ...

# %%
sns.pairplot(df)

# %%
sns.pairplot(df)

# %%
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-dd2f26d85c89> in <module>()
# ----> 1 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
df.describe()
# Out:
#              Number         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#              Length         Width         Depth
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
sns.lmplot(x='price','table', data=df)
# Out:
#   File "<ipython-input-50-334133450781>", line 1
#     sns.lmplot(x='price','table', data=df)
#                         ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.lmplot(x='price', 'table', data=df)
# Out:
#   File "<ipython-input-51-0aefc3d2f682>", line 1
#     sns.lmplot(x='price', 'table', data=df)
#                          ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.lmplot(x='price', y='table', data=df)

# %%
sns.lmplot(x='table', y='price', data=df)

# %%
sns.lmplot(x='table', y='price', data=df, hue='Clarity')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-eb5faf21dbe2> in <module>()
# ----> 1 sns.lmplot(x='table', y='price', data=df, hue='Clarity')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     550     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     551     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 552     data = data[cols]
#     553
#     554     # Initialize the grid
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
sns.lmplot(x='table', y='price', data=df, hue='carat')

# %%
sns.lmplot(x='table', y='price', data=df, hue='cut')

# %%
plt.sybplots(figsize=(13,7))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-c51331d79162> in <module>()
# ----> 1 plt.sybplots(figsize=(13,7))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sybplots'

# %%
plt.subplots(figsize=(13,7))
# Out:
# (<matplotlib.figure.Figure at 0x1c72aefd908>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c72cb157f0>)

# %%
plt.subplots(figsize=(13,7))
sns.violinplot(x='table', y='price', palette=df, hue='cut')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-02c2e79fc721> in <module>()
#       1 plt.subplots(figsize=(13,7))
# ----> 2 sns.violinplot(x='table', y='price', palette=df, hue='cut')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2343                              bw, cut, scale, scale_hue, gridsize,
#    2344                              width, inner, split, dodge, orient, linewidth,
# -> 2345                              color, palette, saturation)
#    2346
#    2347     if ax is None:
#
# ...

# %%
plt.subplots(figsize=(13,7))
sns.violinplot(x='table', y='price', data=df, palette='cut')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat)
#     176             try:
# --> 177                 palette = mpl_palette(palette, n_colors)
#     178             except ValueError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py in mpl_palette(name, n_colors)
#     405     else:
# --> 406         cmap = mpl.cm.get_cmap(name)
#     407         if cmap is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     168             "Colormap %s is not recognized. Possible values are: %s"
# --> 169             % (name, ', '.join(sorted(cmap_d))))
#     170
#
# ...

# %%
sns.violinplot(x='table', y='price', data=df, palette=cut)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-f7b7b3260932> in <module>()
# ----> 1 sns.violinplot(x='table', y='price', data=df, palette=cut)
#
# NameError: name 'cut' is not defined

# %%
sns.distplot(df['price'])

# %%
sns.distplot(df['carat'])

# %%
sns.countplot(x='table', data=df, palette='cut')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat)
#     176             try:
# --> 177                 palette = mpl_palette(palette, n_colors)
#     178             except ValueError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py in mpl_palette(name, n_colors)
#     405     else:
# --> 406         cmap = mpl.cm.get_cmap(name)
#     407         if cmap is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     168             "Colormap %s is not recognized. Possible values are: %s"
# --> 169             % (name, ', '.join(sorted(cmap_d))))
#     170
#
# ...

# %%
sns.countplot(x='table', data=df, palette=cut)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-b8cf131ad6cf> in <module>()
# ----> 1 sns.countplot(x='table', data=df, palette=cut)
#
# NameError: name 'cut' is not defined

# %%
df.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price  Length  Width  \
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       3   0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       5   0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#    Depth
# 0   2.43
# 1   2.31
# 2   2.31
# 3   2.63
# 4   2.75

# %%
sns.boxplot(data=stats=_df)
# Out:
#   File "<ipython-input-67-a7aa33bf2d05>", line 1
#     sns.boxplot(data=stats=_df)
#                           ^
# SyntaxError: invalid syntax

# %%
sns.boxplot(data=stats_df)

# %%
meangrade = df['price'].mean()
stdgrade = df['price'].std()
toprange = meangrade + stdgrade * 3989.439738  
botraopydf = df.copy() #to not mess up the original df
copydf = copydf.drop(copydf[copydf['price'] > toprange].index)
copydf = copydf.drop(copydf[copydf['price'] < botrange].index)

copydf.head()nge = meangrade - stdgrade * 3989.439738  

c
# Out:
#    Number  carat      cut color clarity  depth  table  price  Length  Width  \
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       3   0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       5   0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#    Depth
# 0   2.43
# 1   2.31
# 2   2.31
# 3   2.63
# 4   2.75

# %%
print(cat_df_Diamonds.csv.isnull().values.sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-12dd13c6043f> in <module>()
# ----> 1 print(cat_df_Diamonds.csv.isnull().values.sum())
#
# NameError: name 'cat_df_Diamonds' is not defined

# %%
Diamrint(Diamonds.csv.isnull().values.sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-6ab00e11f5f6> in <module>()
# ----> 1 Diamrint(Diamonds.csv.isnull().values.sum())
#
# NameError: name 'Diamrint' is not defined

# %%
Diamrint(Diamonds.csv.isnull().values.sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-6ab00e11f5f6> in <module>()
# ----> 1 Diamrint(Diamonds.csv.isnull().values.sum())
#
# NameError: name 'Diamrint' is not defined

# %%
corr = df.corr()

# %%
sns.heatmap(corr, vmin=-1 annot=True)
# Out:
#   File "<ipython-input-74-fe3a3f6c8a12>", line 1
#     sns.heatmap(corr, vmin=-1 annot=True)
#                                   ^
# SyntaxError: invalid syntax

# %%
sns.heatmap(corr, vmin=-1 , annot=True)

# %%
import pandas as pd
import numpy as np

# %%
sns.heatmap(corr, vmin=-1 , annot=True)

# %%
df.cor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-68e85421c810> in <module>()
# ----> 1 df.cor()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cor'

# %%
df.corr()
# Out:
#           Number     carat     depth     table     price    Length     Width  \
# Number  1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440 -0.395843
# carat  -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722
# depth  -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341
# table  -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760
# price  -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421
# Length -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701
# Width  -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000
# Depth  -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772  0.952006
#
#            Depth
# Number -0.399208
# carat   0.953387
# depth   0.094924
# table   0.150929
# price   0.861249
# Length  0.970772
# Width   0.952006
# Depth   1.000000

# %%
df.corr()  # This is what I did at home #
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f6f6606aa2c> in <module>
# ----> 1 df.corr()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("Diamonds.csv")

# %%
df = pd.read
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-fb36211d2273> in <module>
# ----> 1 df = pd.read
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
location = "Diamonds.csv"

# %%
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
sns.lmplot(x='carat',y='price', data=df)
# Out:
# C:\Users\kenbe\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# %matplotlib inline

# %%
df.rename(columns={'Unnamed: 0':'Number'}, inplace = True)

# %%
sns.pairplot(df)

# %%
sns.lmplot(x='table', y='price', data=df, hue='cut')

# %%
sns.heatmap(corr, vmin=-1 , annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e4612e4fea2b> in <module>
# ----> 1 sns.heatmap(corr, vmin=-1 , annot=True)
#
# NameError: name 'corr' is not defined

# %%
df.corr()
# Out:
#           Number     carat     depth     table     price         x         y  \
# Number  1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440 -0.395843
# carat  -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722
# depth  -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341
# table  -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760
# price  -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421
# x      -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701
# y      -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000
# z      -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772  0.952006
#
#                z
# Number -0.399208
# carat   0.953387
# depth   0.094924
# table   0.150929
# price   0.861249
# x       0.970772
# y       0.952006
# z       1.000000

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('price ~ x + y + z', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                 6.470e+04
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):               0.00
# Time:                        20:12:31   Log-Likelihood:            -4.8263e+05
# No. Observations:               53940   AIC:                         9.653e+05
# Df Residuals:                   53936   BIC:                         9.653e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.411e+04     41.763   -337.936      0.000   -1.42e+04    -1.4e+04
# ...

# %%
result = smf.ols('price ~ y + z', data=df).fit()

# %%
results.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-1da58c3af1a3> in <module>
# ----> 1 results.summary()
#
# NameError: name 'results' is not defined

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                 8.723e+04
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):               0.00
# Time:                        20:19:00   Log-Likelihood:            -4.8485e+05
# No. Observations:               53940   AIC:                         9.697e+05
# Df Residuals:                   53937   BIC:                         9.697e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.378e+04     43.211   -318.788      0.000   -1.39e+04   -1.37e+04
# ...

# %%
result = smf.ols(formula='price ~ x + y + z - 1', data=df)

# %%
result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-09a3e673f4ca> in <module>
# ----> 1 result.summary()
#
# AttributeError: 'OLS' object has no attribute 'summary'

# %%
result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-09a3e673f4ca> in <module>
# ----> 1 result.summary()
#
# AttributeError: 'OLS' object has no attribute 'summary'

# %%
result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-09a3e673f4ca> in <module>
# ----> 1 result.summary()
#
# AttributeError: 'OLS' object has no attribute 'summary'

# %%
result = smf.ols(formula='price ~ x + y + z - 1', data=df)

# %%
result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-09a3e673f4ca> in <module>
# ----> 1 result.summary()
#
# AttributeError: 'OLS' object has no attribute 'summary'

# %%
result = smf.ols(formula='price ~ x + y + z - 1', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                 3.432e+04
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):               0.00
# Time:                        21:54:25   Log-Likelihood:            -5.1329e+05
# No. Observations:               53940   AIC:                         1.027e+06
# Df Residuals:                   53937   BIC:                         1.027e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x           1145.0222     71.850     15.936      0.000    1004.196    1285.849
# ...
